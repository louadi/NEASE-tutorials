# %%
import pandas as pd

# %%
from NEASE import nease

# %%
table=pd.read_table('data/MIN_MAX.deltapsi.tsv')
# Out:
# /nfs/home/users/zaka/.conda/envs/z/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (8,9,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
table
# Out:
#                     Gene ID                                      LSV ID  \
# 0      gene:ENSG00000084754    gene:ENSG00000084754:t:26230192-26230294
# 1      gene:ENSG00000198860  gene:ENSG00000198860:s:184051651-184051890
# 2      gene:ENSG00000169826    gene:ENSG00000169826:t:43175951-43176032
# 3      gene:ENSG00000150687    gene:ENSG00000150687:t:86807631-86811233
# 4      gene:ENSG00000127952    gene:ENSG00000127952:s:76028642-76028703
# ...                     ...                                         ...
# 85200  gene:ENSG00000082805      gene:ENSG00000082805:t:1289852-1290012
# 85201  gene:ENSG00000198792    gene:ENSG00000198792:t:38219291-38221746
# 85202  gene:ENSG00000129566    gene:ENSG00000129566:s:20369344-20369576
# 85203  gene:ENSG00000069849  gene:ENSG00000069849:t:141902136-141902227
# 85204  gene:ENSG00000197879      gene:ENSG00000197879:s:1471071-1471108
#
#                         LSV Type  \
# 0              t|1e1.1o1|1e2.2o2
# ...

# %%
events=nease.run(table, organism='Human',input_type='MAJIQ')
# Out:
# Processing MAJIQ format...
# MAJIQ output converted successfully to NEASE format.
#
# 		Data Summary
# **************************************************
# 2 protein domains are affected by AS.
# 0 linear motifs are affected by AS.
# 2 of the affected domains have known interactions.
# 2 protein interactions/binding affected.
#
# **************************************************
# Running enrichment analysis...
# NEASE enrichment done.

# %%
events.pdb_affected
# Out:
# Empty DataFrame
# Columns: [symbol, Gene stable ID, entrezgene, NCBI gene ID]
# Index: []

# %%
events.enrich().head(15)
# Out:
# NEASE enrichment for the pathway databases:
#  ['PharmGKB', 'HumanCyc', 'Wikipathways', 'Reactome', 'KEGG', 'SMPDB', 'Signalink', 'NetPath', 'EHMN', 'INOH', 'BioCarta', 'PID']
# No enrichment found with the cutoff 0.05.
#        Pathway ID                                            Pathway name  \
# 0   R-HSA-8978868                                   Fatty acid metabolism
# 1    R-HSA-556833                                    Metabolism of lipids
# 2   R-HSA-9027604  Biosynthesis of electrophilic ?-3 PUFA oxo-derivatives
# 3       PWY66-393                  aspirin-triggered lipoxin biosynthesis
# 4       PWY66-394               aspirin triggered resolvin E biosynthesis
# 5       PWY66-395               aspirin triggered resolvin D biosynthesis
# 6   R-HSA-2142770       Synthesis of 15-eicosatetraenoic acid derivatives
# 7   R-HSA-9018683                        Biosynthesis of DPA-derived SPMs
# 8   R-HSA-9018679                        Biosynthesis of EPA-derived SPMs
# ...

# %%
events.classic_enrich(['Reactome_2016'])
# Out:
# 2021-09-27 21:01:49,061 Warning: No enrich terms using library Reactome_2016 when cutoff = 0.05
#          Gene_set  \
# 0   Reactome_2016
# 1   Reactome_2016
# 2   Reactome_2016
# 3   Reactome_2016
# 4   Reactome_2016
# 5   Reactome_2016
# 6   Reactome_2016
# 7   Reactome_2016
# 8   Reactome_2016
# 9   Reactome_2016
# 10  Reactome_2016
# 11  Reactome_2016
# 12  Reactome_2016
# 13  Reactome_2016
# 14  Reactome_2016
# 15  Reactome_2016
# 16  Reactome_2016
# 17  Reactome_2016
# 18  Reactome_2016
# 19  Reactome_2016
# 20  Reactome_2016
# 26  Reactome_2016
# 24  Reactome_2016
# 25  Reactome_2016
# 22  Reactome_2016
# 21  Reactome_2016
# 23  Reactome_2016
# 27  Reactome_2016
# 28  Reactome_2016
# 29  Reactome_2016
# 30  Reactome_2016
# 31  Reactome_2016
# 32  Reactome_2016
# 33  Reactome_2016
# 34  Reactome_2016
# 35  Reactome_2016
# 36  Reactome_2016
# 38  Reactome_2016
# 37  Reactome_2016
# 39  Reactome_2016
# 40  Reactome_2016
# 41  Reactome_2016
# 42  Reactome_2016
# ...
