# %%
from NEASE import nease

import pandas as pd

# %%
whippet=pd.read_table('ds_OUTPUT/output.diff')

# %%
events=nease.run(whippet, organism='Human',input_type='Whippet')
# Out:
# 		Data Summary
# **************************************************
# 12759 protein domains are affected by AS.
#
# 168 linear motifs are affected by AS.
# 1537 interacting resiude are affected by AS.
#
# 6650 of the affected domains/motifs have known interactions.
# 51773 protein interactions/binding affected.
#
# **************************************************
# Running enrichment analysis...

# %%
whippet
# Out:
#                  Gene                 Node Coord Strand      Type     Psi_A  \
# ENSG00000049239     2    1:9239844-9240018     +     CE  0.995030  0.995250
# ENSG00000049239     3    1:9244925-9245561     +     CE  0.994150  0.994120
# ENSG00000049239     4    1:9246966-9247083     +     CE  0.994000  0.993510
# ENSG00000049239     5    1:9262059-9262328     +     AL  0.010598  0.011286
# ENSG00000284678     2  1:39812935-39813006     -     CE  0.995000  0.995050
# ...               ...                  ...   ...    ...       ...       ...
# ENSG00000235059    11  Y:22482663-22482859     +     CE  0.880270  0.883060
# ENSG00000183146     2  Y:21383913-21383969     -     AF  0.035849  0.033806
# ENSG00000183146     3  Y:21383432-21383796     -     CE  0.983620  0.983370
# ENSG00000185700     3    Y:6472813-6473017     -     CE  0.864400  0.856330
# ENSG00000185700     4    Y:6471031-6471220     -     CE  0.871930  0.876510
#
# ...

# %%
whippet=whippet.rename_axis('Gene ID').reset_index()

# %%
whippet['tmp']=whippet['Node'].apply(lambda x: x.split(':')[1])

# %%
whippet['start']=whippet['tmp'].apply(lambda x: x.split('-')[0])
whippet['end']=whippet['tmp'].apply(lambda x: x.split('-')[1])

# %%
whippet
# Out:
#                 Gene ID  Gene                 Node Coord Strand      Type  \
# 0       ENSG00000049239     2    1:9239844-9240018     +     CE  0.995030
# 1       ENSG00000049239     3    1:9244925-9245561     +     CE  0.994150
# 2       ENSG00000049239     4    1:9246966-9247083     +     CE  0.994000
# 3       ENSG00000049239     5    1:9262059-9262328     +     AL  0.010598
# 4       ENSG00000284678     2  1:39812935-39813006     -     CE  0.995000
# ...                 ...   ...                  ...   ...    ...       ...
# 112535  ENSG00000235059    11  Y:22482663-22482859     +     CE  0.880270
# 112536  ENSG00000183146     2  Y:21383913-21383969     -     AF  0.035849
# 112537  ENSG00000183146     3  Y:21383432-21383796     -     CE  0.983620
# 112538  ENSG00000185700     3    Y:6472813-6473017     -     CE  0.864400
# 112539  ENSG00000185700     4    Y:6471031-6471220     -     CE  0.871930
#
#            Psi_A     Psi_B  DeltaPsi Probability  Complexity  Entropy  \
# ...

# %%
rmats=pd.read_table('ds_OUTPUT/SE.MATS.JC.txt',error_bad_lines=False)
# Out:
# /nfs/home/users/zaka/.conda/envs/z/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
rmats
# Out:
#         ID           GeneID  geneSymbol    chr strand  exonStart_0base  \
# 0        0  ENSG00000261740         NaN  chr16      -         29444397
# 1        1  ENSG00000240505         NaN  chr17      -         16932170
# 2        2  ENSG00000254505         NaN  chr14      -         24210347
# 3        5  ENSG00000104880         NaN  chr19      +          7458511
# 4        6  ENSG00000147586         NaN   chr8      -         79957802
# ...    ...              ...         ...    ...    ...              ...
# 1440  4860  ENSG00000117691         NaN   chr1      +        212434704
# 1441  4867  ENSG00000283930         NaN  chr10      +         38267279
# 1442  4870  ENSG00000286423         NaN  chr14      -         71239945
# 1443  4872  ENSG00000272655         NaN   chr7      -         44016455
# 1444  4877  ENSG00000078399         NaN   chr7      -         27170430
#
#         exonEnd  upstreamES  upstreamEE  downstreamES  ...  SJC_SAMPLE_1  \
# ...

# %%
rmats['PValue']<.05
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1440    False
# 1441    False
# 1442    False
# 1443    False
# 1444    False
# Name: PValue, Length: 1445, dtype: bool

# %%
events=nease.run(rmats, organism='Human',input_type='rmats')
# Out:
# 		Data Summary
# **************************************************
# 47 protein domains are affected by AS.
#
# 0 linear motifs are affected by AS.
# 9 interacting resiude are affected by AS.
#
# 17 of the affected domains/motifs have known interactions.
# 126 protein interactions/binding affected.
#
# **************************************************
# Running enrichment analysis...
# NEASE enrichment done.

# %%
spladder=pd.read_table('ds_OUTPUT/test_results_C3_exon_skip.tsv',error_bad_lines=False)
# Out:
# /nfs/home/users/zaka/.conda/envs/z/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
spladder
# Out:
#            event_id             gene     p_val  p_val_adj  mean_event_count_A  \
# 0    exon_skip_1347  ENSG00000249839  0.000384   0.060211           84.291451
# 1    exon_skip_3278  ENSG00000113532  0.003847   0.208918            8.797195
# 2    exon_skip_3481  ENSG00000153975  0.003992   0.208918           16.517630
# 3    exon_skip_3325  ENSG00000234540  0.006135   0.240814           17.548155
# 4    exon_skip_1120  ENSG00000258744  0.007932   0.249056            1.421693
# ..              ...              ...       ...        ...                 ...
# 152  exon_skip_2986  ENSG00000174796  0.968963   0.988294            2.431162
# 153  exon_skip_3489  ENSG00000093134  0.969410   0.988294            3.913814
# 154  exon_skip_1997  ENSG00000065000  0.989366   0.995023            4.237690
# 155  exon_skip_4175  ENSG00000275352  0.993317   0.995023            2.500514
# 156  exon_skip_2712  ENSG00000230082  0.995023   0.995023           13.278956
#
# ...

# %%
spladder.columns
# Out:
# Index(['event_id', 'gene', 'p_val', 'p_val_adj', 'mean_event_count_A',
#        'mean_event_count_B', 'log2FC_event_count', 'mean_gene_exp_A',
#        'mean_gene_exp_B', 'log2FC_gene_exp'],
#       dtype='object')

# %%
spladder['Star_mapped_subsample_01_Aligned.out.sorted:psi']
# Out:
# 0      0.99
# 1      0.82
# 2      0.82
# 3       NaN
# 4      0.95
#        ...
# 156     NaN
# 157     NaN
# 158    0.43
# 159    0.62
# 160     NaN
# Name: Star_mapped_subsample_01_Aligned.out.sorted:psi, Length: 161, dtype: float64

# %%
import mygene

# %%
mygene.__version__
# Out:
# '3.2.2'

# %%
dexeq=pd.read_csv('ds_OUTPUT/dexseq_test_10mln_3vs3',error_bad_lines=False)
# Out:
# /nfs/home/users/zaka/.conda/envs/z/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
dexeq
# Out:
#                                                                                            Unnamed: 0  \
# ENSG00000004660:E001                                                                  ENSG00000004660
# ENSG00000004660:E002                                                                  ENSG00000004660
# ENSG00000004660:E003                                                                  ENSG00000004660
# ENSG00000004660:E008                                                                  ENSG00000004660
# ENSG00000004660:E009                                                                  ENSG00000004660
# ...                                                                                               ...
# ENSG00000287856+ENSG00000135766+ENSG00000233461:E010  ENSG00000287856+ENSG00000135766+ENSG00000233461
# ENSG00000287856+ENSG00000135766+ENSG00000233461:E014  ENSG00000287856+ENSG00000135766+ENSG00000233461
# ...

# %%
dexeq.columns
# Out:
# Index(['Unnamed: 0', 'groupID', 'featureID', 'exonBaseMean', 'dispersion',
#        'stat', 'pvalue', 'padj', 'case', 'control', 'log2fold_control_case',
#        'genomicData.seqnames', 'genomicData.start', 'genomicData.end',
#        'genomicData.width', 'genomicData.strand',
#        'countData.Star_mapped_subsample_01_Aligned.out.sorted.txt',
#        'countData.Star_mapped_subsample_02_Aligned.out.sorted.txt',
#        'countData.Star_mapped_subsample_03_Aligned.out.sorted.txt',
#        'countData.Star_mapped_subsample_11_Aligned.out.sorted.txt',
#        'countData.Star_mapped_subsample_12_Aligned.out.sorted.txt',
#        'countData.Star_mapped_subsample_13_Aligned.out.sorted.txt',
#        'transcripts'],
#       dtype='object')

# %%
dexeq['genomicData.start']
# Out:
# ENSG00000004660:E001                                      3862283
# ENSG00000004660:E002                                      3866011
# ENSG00000004660:E003                                      3869615
# ENSG00000004660:E008                                      3880434
# ENSG00000004660:E009                                      3882564
#                                                           ...
# ENSG00000287856+ENSG00000135766+ENSG00000233461:E010    231422287
# ENSG00000287856+ENSG00000135766+ENSG00000233461:E014    231522790
# ENSG00000287877:E004                                    165077495
# ENSG00000287884:E001                                      4693722
# ENSG00000288520+ENSG00000153721+ENSG00000074706:E001    154159827
# Name: genomicData.start, Length: 1006, dtype: int64

# %%
dexeq['']
